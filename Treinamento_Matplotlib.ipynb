# %% [markdown]
# <a href="https://colab.research.google.com/github/joceliovieira/treinamento_data_viz/blob/main/Treinamento_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Universidade Federal da Paraíba
# # Treinamento **Matplotlib**
# Autor: Eng° Jocélio Vieira (jocelio.vieira@cear.ufpb.br) - Membro Smart Grid Group (UFPB)
#
# Notebook dedicado à exposição e demonstração de funcionalidades da biblioteca Matplotlib.
#
# [Repositório Github do Notebook e dados](https://github.com/joceliovieira/treinamento_data_viz)
#
# ---
#
# ### Referências
# - [Documentação Oficial: Matplotlib](https://matplotlib.org/stable/index.html)
# - [Tutorial Introdutório: Matplotlib](https://matplotlib.org/stable/tutorials/introductory/usage.html)
# - [Tutorial: Pyplot](https://matplotlib.org/stable/tutorials/introductory/pyplot.html)
# - [Overview: Módulo Pyplot](https://matplotlib.org/stable/api/pyplot_summary.html)
# - [Guia do Usuário: Matplotlib](https://matplotlib.org/stable/users/index.html)
# - [Tipos de Gráficos: Matplotlib](https://matplotlib.org/stable/plot_types/index.html)
# - [Exemplos](https://matplotlib.org/stable/gallery/index.html)
# - [Notebook Introdutório Google Colab: Gráficos](https://colab.research.google.com/notebooks/charts.ipynb)
# - [Inverse Distance Weighting (IDW) Interpolation - Rafael Tieppo](https://rafatieppo.github.io/post/2018_07_27_idw2pyr/)
# - Livros
#   - Data science do zero: primeiras regras com o Python - Joel Grus
#
# ---
#
# Dados - Radiação: https://raw.githubusercontent.com/joceliovieira/treinamento_data_viz/main/data/rad_jp.csv

# %% [markdown]
# ## Instalação da versão atualizada
#     pip install --upgrade matplotlib
#
# #### Conferindo a instalação
# O comando a seguir retorna uma lista de informações de um ou mais pacotes instalados.
#
#     pip show matplotlib

# %%
# !pip install --upgrade matplotlib
# Out:
# ...
#      |████████████████████████████████| 11.2 MB 4.7 MB/s
# ...
#      |████████████████████████████████| 895 kB 46.6 MB/s
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...

# %%
# !pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.5.1
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: PSF
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: numpy, packaging, kiwisolver, pyparsing, cycler, fonttools, pillow, python-dateutil
# Required-by: yellowbrick, seaborn, scikit-image, pycocotools, plotnine, pandas-profiling, mlxtend, mizani, missingno, matplotlib-venn, keras-vis, imgaug, fbprophet, fastai, descartes, daft, arviz

# %% [markdown]
# ## Importando os pacotes para o ambiente de desenvolvimento

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Introdução
# O Matplotlib é baseado em Figuras (_figures_), que podem conter um ou mais eixos (onde serão, de fato, plotados os gráficos).
#
# A construção de um gráfico se baseia em um estado interno que pode ser construído passo a passo. Ao fim, é possível salvar a figura ou exibi-la.
#
# No primeiro exemplo, será criada uma figura simples, com um único eixo. Depois, será demonstrado como trabalhar com múltiplos gráficos (eixos) na mesma figura.
#
# Obs.: No caso, o eixo referido é o eixo de plotagem, e não (X, Y).
#
# ### Figure
# Para iniciar um gráfico, é interessante a criação do objeto figura, através do seguinte comando.
#
#     plt.figure()
#
# Parâmetros de interesse:
# - Figsize: figsize = (largura, altura)
#
# Após a criação da figura, seguiremos com a criação dos gráficos.
#
# ### Plot
# Função: Plota os valores y versus x em um gráfico de linhas podendo conter marcadores.
#
# Utilização básica:
#
#     plt.plot([X], Y) # onde o X é opcional.
#
# > Referência: [Matplotlib plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot)
#
# A função _plot_ pode ser chamada diretamente (plt.plot()) ou especificando sobre qual eixo irá atuar (ax1.plot(), ax2.plot()).
#
# Estas 2 situações serão demonstradas abaixo.
#
# #### Parâmetros (plot)
#
# Além da plotagem básica, pode-se inserir parâmetros opcionais para customizar os gráficos. Alguns destes serão demonstrados a seguir.
#
# Exemplos:
# - linewidth: largura da linha
# - linestyle: estilo da linha
# - color: cor da linha
# - marker: tipo de marcador
# - markersize: tamanho de marcador
# - markerfacecolor: cor do marcador
#
# ### Show
# Exibe a(s) figura(s) criada(s).
#
#     plt.show()
#
# ### Savefig
# Utiliza-se, ao fim da construção da figura, para salvá-la.
#
#     plt.savefig(fname)
#
# Parâmetros obrigatórios:
# - fname (string): pode ser apenas o nome da imagem, salvando no diretório atual, ou o caminho completo de onde a imagem deve ser armazenada.
#
# Parâmetros opcionais:
# - dpi (float): resolução da imagem em unidades de pontos por polegada.
# - format (string): formato da imagem.

# %% [markdown]
# ### Iniciando a Prática!

# %%
# Dados
y = [100, 150, 250, 400, 600, 900, 1200]
 
# Plota os dados
plt.plot(y)

# Exibe o gráfico
plt.show()

# %%
# Dados
y = [100, 150, 250, 400, 600, 900, 1200]
 
# Plota os dados
plt.plot(y)

# Salva o gráfico
plt.savefig('exemplo.png')

# %%
# Definindo o eixo X

# Dados
y = [100, 150, 250, 400, 600, 900, 1200]
x = [1960, 1970, 1980, 1990, 2000, 2010, 2020]

# Criando uma figura com tamanho de (10, 5)
plt.figure(figsize=(10,5))

# Plota os valores Y sobre o eixo X com marcadores do tipo circular
plt.plot(x, y, marker = 'o')

# Habilita a grade do gráfico para melhor leitura/visualização
plt.grid() 

# Define o título da figura
plt.title('Gráfico Temporal')

# Exibe o gráfico
plt.show()

# %% [markdown]
# ### Customização de uma Figura/Gráfico
#
# Elementos de uma figura podem ser customizados.
#
#
# <img src="https://matplotlib.org/stable/_images/anatomy.png" width="700"/>
#
# Fonte: https://matplotlib.org/stable/tutorials/introductory/usage.html

# %% [markdown]
# ### Subplots
# [Referência - plt.subplots()](https://matplotlib.org/devdocs/api/_as_gen/matplotlib.pyplot.subplots.html#matplotlib.pyplot.subplots)
#
# Através de subplots é possível plotar diversos gráficos em uma figura única.
#
# Comando básico:
#
#     plt.subplots(n_linhas, n_colunas)
# O comando acima retorna uma figura e um conjunto de subplots (eixos).\
# Iremos, então, atribuir variáveis a esses elementos para que possamos trabalhar com os mesmos, através dos seguintes comandos.
#
#     fig, axs = plt.subplots(n_linhas, n_colunas) # Cria uma figura (fig) com n eixos acessados através de axs[n_linha, n_coluna]
#
#     fig, (ax1, ax2) = plt.subplots(2, 1) # Cria uma figura (fig) com 2 eixos (ax1, ax2)
#
# Para acessar um dos n eixos, utiliza-se o seguinte comando:
#
#     axs[n_linha, n_coluna]
#
# Onde [n_linha, n_coluna] é referente a posição dos gráficos dentro da imagem. Ambos iniciam a contagem em zero.
#
# Os seguintes parâmetros podem ser de interesse.
# - figsize(float, float) - indica o tamanho da figura a ser criada (default: [6.4, 4.8]).
# - sharex, sharey
#     - booleano - indica se os eixos cartesianos X ou Y serão compartilhados pelos subplots.
#     - raw/col (string) - Os eixos cartesianos passar a ser compartilhados nas linhas ou colunas.
#
# > Exemplo: **sharey = 'raw'** indica que o eixo Y será o mesmo para os gráficos pertencentes a uma mesma linha.
#
# Pode-se observar a utilização básica dessa funcionalidade no exemplo a seguir.
#
# Outras aplicações/customizações de subplots podem ser verificadas através da referência indicada acima.

# %%
# Figura com 2 eixos (gráfico)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10,8))  # Cria uma figura (fig) com 2 eixos (ax1, ax2)

ax1.plot([2, 4, 8, 16]) # Plota os valores em ax1
ax2.plot([1, 32, 3, 10]) # Plota os valores em ax1

plt.show() # Exibe a figura

# %% [markdown]
# Será utilizado o seguinte comando para criar uma figura com 6 gráficos dispostos em 3 linhas e 2 colunas.
#
#     fig, axs = plt.subplots(3, 2, figsize = (8,10))
#
# Para acessar um dos 6 eixos, utiliza-se o seguinte comando:
#
#     axs[n1, n2]
#
# Onde n1 e n2 são referentes a posição dos gráficos dentro da imagem. n1 é referente a linha e n2, coluna. Ambos iniciam a contagem em zero.
#
# Portanto, para acessar o gráfico na terceira linha e segunda coluna, utilizariamos os parâmetros n1 = 2 e n2 = 1.

# %%
y = [2, 4, 6, 8]

fig, axs = plt.subplots(3, 2, figsize = (8,10))  # Cria uma figura (fig) com 6 eixos (ax1, ax2) e tamanho de (8, 10)

axs[0, 0].plot(y) # Plota os valores no gráfico na primeira linha/coluna
axs[0, 0].set_title("Plotagem padrão") # Define o título do gráfico 

axs[1, 0].plot(y, linewidth = '5') # Plota os valores no gráfico da segunda linha e primeira coluna
axs[1, 0].set_title("linewidth = '5'") 

axs[2, 0].plot(y, linestyle = '--') # Plota os valores no gráfico da terceira linha e primeira coluna
axs[2, 0].set_title("linestyle = '--'")

axs[0, 1].plot(y, marker = 'o') # Plota os valores no gráfico da primeira linha e segunda coluna
axs[0, 1].set_title("marker = 'o'")

axs[1, 1].plot(y, marker = 'D', markersize='14') # Plota os valores no gráfico da segunda linha e segunda coluna
axs[1, 1].set_title("marker = 'D', markersize='14'")

axs[2, 1].plot(y, marker = 'o', markersize='10', markerfacecolor='red') # Plota os valores no gráfico da terceira linha e segunda coluna
axs[2, 1].set_title("marker = 'o', markersize='10',\nmarkerfacecolor='red'")

# Define o título global da figura, assim como desloca-o para cima com y=1 (default y = 0.95).
fig.suptitle("plt.plot: Parâmetros Adicionais", y=1) 

# Ajusta os espaçamentos e afins, para não haver sobreposição de informações
plt.tight_layout()

# Exibe o(s) gráfico(s) plotado(s)
plt.show()

# %% [markdown]
# ## Tipos de Gráficos
# [Referência Matplotlib: Tipos de Gráfico](https://matplotlib.org/stable/plot_types/index.html)
#
# Além do já exposto gráfico de linha, a biblioteca matplotlib dispõe de diversos tipos de gráficos que podem ser utilizados para exibir informações de diferentes tipos.
#
# Alguns dos mais utilizados são os seguintes.

# %% [markdown]
# ### Gráfico de dispersão
# [Referência: Scatter Plots Matplotlib](https://matplotlib.org/stable/gallery/lines_bars_and_markers/scatter_with_legend.html#sphx-glr-gallery-lines-bars-and-markers-scatter-with-legend-py)
#
# Neste tipo de gráfico pode-se verificar a relação entre 2 variáveis quantitativas.
#
# Através deste gráfico, podem ser obtidas valiosas informações ao observar a relação entre variáveis, como a formação de grupos ou detecção de _outliers_.

# %%
# Dados
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

# Plotagem
fig, ax = plt.subplots(figsize = (12,5))
ax.scatter(x, y)

# Definindo o título e as legendas dos eixos (labels)
plt.suptitle("Gráfico de Dispersão Simples", fontsize=14)
plt.xlabel('Variável 1', fontsize=14)
plt.ylabel('Variável 2', fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# No exemplo abaixo, há a inserção de mais 2 parâmetros que podem ser definidos de acordo com mais variáveis de interesse. São eles: cor e tamanho do "ponto".

# %%
# Gerando dados aleatórios (dados de X, Y, além de cores e tamanho)
N = 45
x, y = np.random.rand(2, N)
cores = np.random.randint(1, 5, size=N)
tamanhos = np.random.randint(10, 220, size=N)

# Criando a figura e plotando os dados
fig, ax = plt.subplots(figsize=(10,5))
scatter = ax.scatter(x, y, c=cores, s=tamanhos)

# Criando legenda para as cores
legend1 = ax.legend(*scatter.legend_elements(), loc="lower left", title="Classes")
ax.add_artist(legend1)

# Criando legenda para os tamanhos
handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6)
legend2 = ax.legend(handles, labels, loc="upper right", title="Sizes")

plt.suptitle("Gráfico de Dispersão com Legendas")
plt.show()

# %% [markdown]
# ### Gráfico de Barras
# Este tipo de gráfico é bastante utilizado visualização de dados onde há classes definidas e representadas por variáveis não-contínuas. Assim, pode-se comparar as classes em relação ao nível de ocorrência das mesmas.

# %%
grupos = ['G1', 'G2', 'G3', 'G4', 'G5']
pontuacao_homens = [20, 34, 30, 35, 27]
pontuacao_mulheres = [25, 32, 34, 20, 25]

x = np.arange(len(grupos))  # Localização dos nomes dos grupos
width = 0.35  # Largura das barras

fig, ax = plt.subplots(figsize=(10,6))
rects1 = ax.bar(x - width/2, pontuacao_homens, width, label='pontuacao_homens')
rects2 = ax.bar(x + width/2, pontuacao_mulheres, width, label='pontuacao_mulheres')

# Definindo título da figura, nomes dos eixos, marcadores do eixo X e habilitando a legenda
ax.set_ylabel('Pontuação')
ax.set_xlabel('Grupo')
ax.set_title('Pontuação por grupo e por gênero')
ax.set_xticks(x, grupos)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Histogramas
# Os histogramas caracterizam-se por dispor uma **variável contínua** com base em sua **distribuição de frequência**.
#
# O gráfico de barras, por sua vez, representa variáveis discretas/categóricas.
#
# Os histogramas podem fornecer informações sobre:
# - Distribuição dos valores de um conjunto de dados
# - Frequência de ocorrência dos dados
# - Valores mais frequentes
# - Tendência central
# - Amplitude
# - Simetria
#
# O número de classes pode impactar a análise sobre os dados em questão.
#
# Exemplo: Distribuição das idades de pessoas que compareceram em determinado evento.
# - Classe 1 - número de pessoas entre 10 e 20 anos
# - Classe 2 - número de pessoas entre 20 e 30 anos
# - Classe 3 - número de pessoas entre 30 e 40 anos.

# %%
# Gerando os dados
idades = np.array([22,5,43,56,73,55,54,11,20,51,5,79,31,27,1,5,90,7,10,13,18])
idades_limite = [0,20,40,60,80,100] # Estas são as idades que irão delimitar os 'grupos'

# Criando a figura e plotando os dados
fig,ax = plt.subplots(1,1, figsize=(10,5))
ax.hist(x = idades, bins = idades_limite)

# Customizando o gráfico
ax.set_title("Distribuição de Idades em determinado evento", fontsize=14)
ax.set_xticks(idades_limite)
ax.set_xlabel('Idade', fontsize=14)
ax.set_ylabel('Quantidade de pessoas', fontsize=14)

plt.grid()
plt.show()

# %%
# Exemplo Adaptado de https://colab.research.google.com/notebooks/charts.ipynb

# Dados
y = 5 + np.random.randn(1000)
x = np.linspace(0,len(y)-1,len(y))

# Plotagem
fig, (ax1,ax2,ax3) = plt.subplots(3,1, figsize=(10,8))

# Visualização dos valores
ax1.bar(x, y)
ax1.set_title("Dados 'Brutos'")

# Histograma Simples
ax2.hist(y, bins=20) # Bins é o número de 'grupos' em que os dados serão dispostos
ax2.set_title("Histograma")

# Histograma Cumulativo
ax3.hist(y, cumulative=True, bins=20)
ax3.set_title("Histograma Cumulativo")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pizza/Pie
# Referência: [Pie Chart](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.pie.html)
#
# O gráfico de pizza demonstra o valor relativo de cada classe do conjunto de dados. Cada classe, portanto, será representada pela relação entre seu valor e o total.

# %%
classes = ['Classe 1', 'Classe 2', 'Classe 3']
valores = [150, 280, 30]

plt.figure(figsize = (10,10))
plt.pie(valores, labels=classes, autopct = '%1.2f%%')
plt.title('Gráfico de Pizza')
plt.show()

# %% [markdown]
# ## Respondendo a Perguntas - Ideias!
#
# O principal objetivo de uma análise de dados é responder perguntas e levantar informações sobre os dados.
#
# Portanto, durante a análise exploratória dos dados, algumas perguntas como as seguintes podem surgir.
#
# - Quais as estatísticas básicas dos dados?
# - Existem anomalias nos dados? (outliers, dados faltantes, formatação equivocada, etc)
# - Como é a distribuição dos dados? (linearidade, simetria, dispersão, clusters, etc)
# - Como é a qualidade dos dados? (dados faltantes, classes desbalanceadas, periodicidade, autocorrelação, normalização, etc)
#
# Para exemplificar algumas dessas situações, utilizaremos um dataset exemplo da biblioteca Seaborn, que traz informações sobre algumas  espécies de flores.

# %%
import seaborn as sns
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Como é a qualidade dos dados?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# O formato dos dados está adequado.

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# Verifica-se que as classes não apresentam dados faltantes.

# %%
df.count()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %%
plt.figure(figsize=(10,6))
df.count().plot(kind = 'bar')
plt.xticks(rotation='horizontal')
plt.plot()
# Out:
# []

# %% [markdown]
# Verifica-se que as classes estão devidamente balanceadas.
#
# #### - Quais as estatísticas básicas dos dados?
# Sugestão: método Pandas df.describe

# %%
df.describe(include='all') # ‘all’ : All columns of the input will be included in the output
# Out:
#         sepal_length  sepal_width  petal_length  petal_width    species
# count     150.000000   150.000000    150.000000   150.000000        150
# unique           NaN          NaN           NaN          NaN          3
# top              NaN          NaN           NaN          NaN  virginica
# freq             NaN          NaN           NaN          NaN         50
# mean        5.843333     3.057333      3.758000     1.199333        NaN
# std         0.828066     0.435866      1.765298     0.762238        NaN
# min         4.300000     2.000000      1.000000     0.100000        NaN
# 25%         5.100000     2.800000      1.600000     0.300000        NaN
# 50%         5.800000     3.000000      4.350000     1.300000        NaN
# 75%         6.400000     3.300000      5.100000     1.800000        NaN
# max         7.900000     4.400000      6.900000     2.500000        NaN

# %% [markdown]
# Analisando a **distribuição** de cada um dos atributos.

# %%
plt.figure(figsize=(10,6))
plt.hist(df['species'])
plt.xlabel("Quantidade")
plt.ylabel("Espécie")
plt.grid()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(16,8))

axs[0,0].hist(df['petal_length'], label = 'petal_length', bins=20)
axs[0,0].legend()

axs[1,0].hist(df['sepal_length'], label = 'sepal_length', bins=20)
axs[1,0].legend()

axs[0,1].hist(df['petal_width'], label = 'petal_width', bins=20)
axs[0,1].legend()

axs[1,1].hist(df['sepal_width'], label = 'sepal_width', bins=20)
axs[1,1].legend()

for ax in axs.flat:
    ax.set(xlabel='Valor', ylabel='Quantidade')

plt.show()

# %% [markdown]
# Através dos gráficos acima é possível verificar os valores mais frequentes em cada uma das classes, assim como os menos frequentes.

# %% [markdown]
# Verificando se há outliers.

# %%
df.plot(kind='box')
plt.show()

# %% [markdown]
# É provável que existam alguns outliers na classe 'sepal_width'

# %% [markdown]
# **Analisando a relação de variáveis com o Gráfico de Dispersão (scatter)  e da biblioteca Seaborn**
#
# A função utilizada será a sns.pairplot() uma vez que ela já traz todos os gráficos de dispersão para o dataset fornecido.

# %%
sns.pairplot(df, hue='species', height=2)
plt.show()

# %% [markdown]
# De forma geral, a espécie Setosa se diferencia das outras 2 espécies em termos de dimensões.

# %% [markdown]
# Outra visualiação da correlação entre as classes - heatmap Seaborn.

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(method='pearson'), annot=True)
plt.show()

# %% [markdown]
# Verificando a alta correlação entre petal_width e petal_length

# %%
plt.figure(figsize=(10,6))
plt.scatter(x='petal_width', y='petal_length', data = df)
plt.xlabel('petal_width')
plt.ylabel('petal_length')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Tratando dados de Radiação
#
# Foram levantados os dados de radiação de João Pessoa.
#
# Será realizada uma breve análise exploratória com visualização dos dados para verificar se os mesmos apresentam alguma inconformidade e, caso apresentem, corrigir.

# %%
caminho = 'https://raw.githubusercontent.com/joceliovieira/treinamento_data_viz/main/data/rad_jp.csv'
df_jp = pd.read_csv(caminho,
                    delimiter=';',
                    names=['DATA','HORA','RAD_KJM2'],
                    header=9, 
                    decimal=',',
                    index_col= False
                    )
df_jp.head()
# Out:
#          DATA  HORA  RAD_KJM2
# 0  2009-01-01     0    -3.540
# 1  2009-01-01   100    -3.540
# 2  2009-01-01   200    -3.540
# 3  2009-01-01   300    -3.423
# 4  2009-01-01   400    -3.540

# %% [markdown]
# ### Análise exploratória e tratamento inicial dos dados

# %%
df_jp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96408 entries, 0 to 96407
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DATA      96408 non-null  object
#  1   HORA      96408 non-null  int64
#  2   RAD_KJM2  75698 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
df_jp.head(10)
# Out:
#          DATA  HORA  RAD_KJM2
# 0  2009-01-01     0    -3.540
# 1  2009-01-01   100    -3.540
# 2  2009-01-01   200    -3.540
# 3  2009-01-01   300    -3.423
# 4  2009-01-01   400    -3.540
# 5  2009-01-01   500    -3.537
# 6  2009-01-01   600    -3.537
# 7  2009-01-01   700    -3.526
# 8  2009-01-01   800    -3.540
# 9  2009-01-01   900    52.466

# %%
# Padronizando o formato de dados, para converter para hora e depois alterar o fuso horário
list = []
for i in df_jp['HORA']:
    if i == 0:
        a = '000' + str(i)
        list.append(a)
    elif i in [100,200,300,400,500,600,700,800,900]: 
        a = '0' + str(i)
        list.append(a)    
    else:
        a = str(i)
        list.append(a)

print(list[:24])
# Out:
# ['0000', '0100', '0200', '0300', '0400', '0500', '0600', '0700', '0800', '0900', '1000', '1100', '1200', '1300', '1400', '1500', '1600', '1700', '1800', '1900', '2000', '2100', '2200', '2300']

# %% [markdown]
# ### Atribuindo uma Coluna para os dados de hora 'convertidos' e criando uma coluna para data+hora, que servirá de índice (index)

# %%
df_jp['HORA_CONV'] = list
df_jp['DATA_HORA'] = df_jp['DATA'] + ' ' + df_jp['HORA_CONV']
df_jp.head()
# Out:
#          DATA  HORA  RAD_KJM2 HORA_CONV        DATA_HORA
# 0  2009-01-01     0    -3.540      0000  2009-01-01 0000
# 1  2009-01-01   100    -3.540      0100  2009-01-01 0100
# 2  2009-01-01   200    -3.540      0200  2009-01-01 0200
# 3  2009-01-01   300    -3.423      0300  2009-01-01 0300
# 4  2009-01-01   400    -3.540      0400  2009-01-01 0400

# %% [markdown]
# Removendo as colunas não mais necessárias (data, hora e hora_conv), e convertendo o formato de data_hora.

# %%
df_jp.drop(columns=['DATA', 'HORA', 'HORA_CONV'], inplace=True)
df_jp.head()
# Out:
#    RAD_KJM2        DATA_HORA
# 0    -3.540  2009-01-01 0000
# 1    -3.540  2009-01-01 0100
# 2    -3.540  2009-01-01 0200
# 3    -3.423  2009-01-01 0300
# 4    -3.540  2009-01-01 0400

# %% [markdown]
# Convertendo o tipo de data_hora de String para Datetime

# %%
print(df_jp.info())
df_jp['DATA_HORA'] = pd.to_datetime(df_jp['DATA_HORA'],format="%Y-%m-%d %H%M")
print(df_jp.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96408 entries, 0 to 96407
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   RAD_KJM2   75698 non-null  float64
#  1   DATA_HORA  96408 non-null  object
# dtypes: float64(1), object(1)
# memory usage: 1.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96408 entries, 0 to 96407
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   RAD_KJM2   75698 non-null  float64
#  1   DATA_HORA  96408 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.5 MB
# None

# %% [markdown]
# #### Convertendo o fuso horário e atribuindo a coluna data_hora ao índice do Dataframe

# %%
df_jp.set_index(df_jp['DATA_HORA'], inplace=True)
df_jp['DATA_HORA_RECIFE'] = df_jp['DATA_HORA'].apply(lambda x: df_jp['DATA_HORA'][x].tz_localize('UTC').tz_convert('America/Recife'))
df_jp = df_jp.set_index(df_jp['DATA_HORA_RECIFE']).drop(columns=['DATA_HORA','DATA_HORA_RECIFE'])
df_jp.index.names = ['DATA_HORA']
df_jp.head()
# Out:
#                            RAD_KJM2
# DATA_HORA
# 2008-12-31 21:00:00-03:00    -3.540
# 2008-12-31 22:00:00-03:00    -3.540
# 2008-12-31 23:00:00-03:00    -3.540
# 2009-01-01 00:00:00-03:00    -3.423
# 2009-01-01 01:00:00-03:00    -3.540

# %% [markdown]
# Removendo os itens iniciais anteriores a 2010

# %%
df_jp.drop(df_jp['RAD_KJM2'].index[:3], inplace=True)
df_jp.head()
# Out:
#                            RAD_KJM2
# DATA_HORA
# 2009-01-01 00:00:00-03:00    -3.423
# 2009-01-01 01:00:00-03:00    -3.540
# 2009-01-01 02:00:00-03:00    -3.537
# 2009-01-01 03:00:00-03:00    -3.537
# 2009-01-01 04:00:00-03:00    -3.526

# %% [markdown]
# Convertendo as unidades de radiação e criando uma coluna para os dados em kWh/m²

# %%
df_jp['RAD_KWHM2'] = (df_jp['RAD_KJM2']/3600).round(2)
df_jp.drop(columns='RAD_KJM2', inplace = True)
df_jp.head()
# Out:
#                            RAD_KWHM2
# DATA_HORA
# 2009-01-01 00:00:00-03:00       -0.0
# 2009-01-01 01:00:00-03:00       -0.0
# 2009-01-01 02:00:00-03:00       -0.0
# 2009-01-01 03:00:00-03:00       -0.0
# 2009-01-01 04:00:00-03:00       -0.0

# %% [markdown]
# ### Análise numérica

# %%
display(df_jp.describe())
# Out:
#           RAD_KWHM2
# count  75695.000000
# mean       0.244377
# std        0.331005
# min       -0.000000
# 25%       -0.000000
# 50%        0.010000
# 75%        0.500000
# max        1.360000

# %%
print("Valor máximo: " + str(df_jp['RAD_KWHM2'].max()))
print("Valor mínimo: " + str(df_jp['RAD_KWHM2'].min()))

print("Dados acima de 1 kWh/m²: {}".format(df_jp[df_jp['RAD_KWHM2'] > 1].count()[0]))
print("Dados acima de 1.35 kWh/m²: {}".format(df_jp[df_jp['RAD_KWHM2'] > 1.35].count()[0]))
# Out:
# Valor máximo: 1.36
# Valor mínimo: -0.0
# Dados acima de 1 kWh/m²: 1127
# Dados acima de 1.35 kWh/m²: 2

# %%
df_jp['RAD_KWHM2'].isna().sum() # Apresenta 20710 NaN
# Out:
# 20710

# %%
df_jp.plot(figsize=(10,6))
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(df_jp['RAD_KWHM2'].rolling(6).mean().round(2))
plt.ylabel('Moving Average: Radiação Global (kJ/m²)')
plt.show()

# %%
df_jp['RAD_INT_KWHM2'] = df_jp['RAD_KWHM2'].interpolate(method = 'pad')
df_jp.isna().sum()
# Out:
# RAD_KWHM2        20710
# RAD_INT_KWHM2        0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.plot(df_jp['RAD_INT_KWHM2'])
plt.show()

# %% [markdown]
# A técnica acima não apresentou comportamento ideal, uma vez que apenas preencheu com um valor médio grandes intervalos de tempo. Para melhorar tal preenchimento de valores ausentes, pode-se utilizar de técnicas como a interpolação por inverso da distância ou inverse distance weighting (IDW), que relaciona dados de localizações próximas ao dado ausente e fornece um valor aproximado para o mesmo.
#
# Recomendação de leitura: [Inverse Distance Weighting (IDW) for python and R. Autor: Rafael Tieppo.](https://rafatieppo.github.io/post/2018_07_27_idw2pyr/)
